# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Chitresh\\Documents'

# %%
os.chdir('C:\\Users\\Chitresh\\Desktop\\Python DataScience A-Z')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Chitresh\\Desktop\\Python DataScience A-Z'

# %%
movie = pd.read_csv('Movie-Ratings.csv')

# %%
len(movie)
# Out:
# 559

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillions',\
                'Year']

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 21.9+ KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movie.Film =movie.Film.astype('category')

# %% [markdown]
# movie.head()

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 23.0+ KB

# %%
movie.Genre = movie.Genre.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(2), int64(4)
# memory usage: 21.4 KB

# %%
movie.Year = movie.Year.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 17.6 KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movie.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Joint Plot

# %%
j = sns.jointplot(data=movie,x='CriticRating',y='AudienceRating')

# %%
j = sns.jointplot(data=movie,x='CriticRating',y='AudienceRating',kind='hex')

# %%
m1 = sns.distplot(movie.AudienceRating,bins=15)

# %%
m2 = sns.distplot(movie.CriticRating,bins=15)

# %%
sns.set_style("dark")
n1 = plt.hist(movie.AudienceRating,bins=15)

# %%
n2 = plt.hist(movie.CriticRating,bins=15)

# %%
#plt.hist(movie.BudgetMillions)

# %%
movie[movie.Genre == 'Drama'].BudgetMillions
# Out:
# 10      30
# 11      20
# 13       7
# 18       8
# 23      20
# 26       8
# 27      30
# 47      13
# 53      26
# 55       2
# 56      55
# 62      55
# 74      15
# 84      25
# 96      37
# 99      25
# 112     60
# 116     21
# 117      5
# 119     31
# 120     40
# 128      1
# 131     24
# 132     21
# 151     33
# 158     16
# 171      7
# 195     15
# 199     35
# 213     10
#       ...
# 437     13
# 442     20
# 444      2
# 445     20
# 446     40
# 450     65
# 457     40
# 466     45
# 467     11
# 470     60
# 480     39
# 482     32
# 483     68
# 484     50
# 487      0
# 488      4
# 489    150
# 490     16
# 492     25
# 508     20
# 509     10
# 511      2
# 516     25
# 523     26
# 527     70
# 529     66
# 532     38
# 534     21
# 541     15
# 545      2
# Name: BudgetMillions, dtype: int64

# %%
plt.hist(movie[movie.Genre == 'Drama'].BudgetMillions,bins=15)
plt.hist(movie[movie.Genre == 'Action'].BudgetMillions,bins=15)
plt.hist(movie[movie.Genre == 'Thriller'].BudgetMillions,bins=15)
plt.show()

# %%
plt.hist([movie[movie.Genre == 'Drama'].BudgetMillions,movie[movie.Genre == 'Thriller'].BudgetMillions,\
          movie[movie.Genre == 'Action'].BudgetMillions],bins=15,stacked=True)
plt.show()

# %%
for gen in movie.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = []
mylabels = list()
for gen in movie.Genre.cat.categories:
    list1.append(movie[movie.Genre == gen].BudgetMillions)
    mylabels.append(gen)
h = plt.hist(list1,bins=15,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
#KDE Plot

# %%
vis1 = sns.lmplot(data=movie,x='CriticRating',y='AudienceRating',\
                 fit_reg=False,hue='Genre',\
                 size=7,aspect=2)

# %%
k1 = sns.kdeplot(movie.CriticRating,movie.AudienceRating,shade=True,shade_lowest=False)
k1b = sns.kdeplot(movie.CriticRating,movie.AudienceRating,cmap='Reds')

# %%
#working with sub-plots

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
k1 = sns.kdeplot(movie.BudgetMillions,movie.AudienceRating)

# %%
k1 = sns.kdeplot(movie.BudgetMillions,movie.CriticRating)

# %%
f,axes = plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
k1 = sns.kdeplot(movie.BudgetMillions,movie.AudienceRating,ax=axes[0])
k1 = sns.kdeplot(movie.BudgetMillions,movie.CriticRating,ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#violin plots vs box plots

# %%
z = sns.violinplot(data=movie,x='Genre',y='CriticRating')

# %%
z = sns.boxplot(data=movie,x='Genre',y='CriticRating')

# %%
z = sns.violinplot(data=movie[movie.Genre=='Drama'],x='Year',y='CriticRating')

# %%
z = sns.boxplot(data=movie[movie.Genre=='Drama'],x='Year',y='CriticRating')

# %%
#Facet Grid

# %%
g = sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')

# %%
g = sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
kws = dict(s=80,linewidth=0.9,edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %%
g = sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black')
g = g.map(plt.hist,'CriticRating')

# %%
#Controlling axes and adding diagonals

# %%
g = sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
kws = dict(s=80,linewidth=0.9,edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim(0,100),ylim(0,100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f424a2dff1ea> in <module>()
# ----> 1 g = sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
#       2 kws = dict(s=80,linewidth=0.9,edgecolor='black')
#       3 g = g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
#       4 g.set(xlim(0,100),ylim(0,100))
#
# NameError: name 'sns' is not defined

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
g = sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
kws = dict(s=80,linewidth=0.9,edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0a6bb8b8a6e3> in <module>()
# ----> 1 g = sns.FacetGrid(movie,row='Genre',col='Year',hue='Genre')
#       2 kws = dict(s=80,linewidth=0.9,edgecolor='black')
#       3 g = g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
#       4 g.set(xlim=(0,100),ylim=(0,100))
#
# NameError: name 'movie' is not defined
